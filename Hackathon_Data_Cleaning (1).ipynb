# %%
import pandas as pd

# %%
district_data = pd.read_csv('/content/EducationDataPortal_04.07.2023_School Districts (3).csv')
district_data.head(50)
# Out:
#                    year   leaid                                      lea_name  \
# 0   mixed - most recent  200050                Alaska Gateway School District
# 1   mixed - most recent  200010               Aleutian Region School District
# 2   mixed - most recent  200007        Aleutians East Borough School District
# 3   mixed - most recent  200180                     Anchorage School District
# 4   mixed - most recent  200525                Annette Island School District
# 5   mixed - most recent  200020                 Bering Strait School District
# 6   mixed - most recent  200030           Bristol Bay Borough School District
# 7   mixed - most recent  200730                       Chatham School District
# 8   mixed - most recent  200800                       Chugach School District
# 9   mixed - most recent  200070                  Copper River School District
# 10  mixed - most recent  200060                  Cordova City School District
# ...

# %%
district_data.shape
# Out:
# (19507, 27)

# %%
district_data = district_data.dropna()
district_data.head(50)
# Out:
#                    year   leaid                                      lea_name  \
# 0   mixed - most recent  200050                Alaska Gateway School District
# 1   mixed - most recent  200010               Aleutian Region School District
# 2   mixed - most recent  200007        Aleutians East Borough School District
# 3   mixed - most recent  200180                     Anchorage School District
# 4   mixed - most recent  200525                Annette Island School District
# 5   mixed - most recent  200020                 Bering Strait School District
# 6   mixed - most recent  200030           Bristol Bay Borough School District
# 7   mixed - most recent  200730                       Chatham School District
# 8   mixed - most recent  200800                       Chugach School District
# 9   mixed - most recent  200070                  Copper River School District
# 10  mixed - most recent  200060                  Cordova City School District
# ...

# %%
district_data.shape
# Out:
# (10141, 27)

# %%
for col in district_data.columns:
  district_data = district_data[district_data[col] != 'Missing/not reported']

# %%
district_data.shape
# Out:
# (10137, 27)

# %%
district_data.head()
# Out:
#                   year   leaid                                lea_name  \
# 0  mixed - most recent  200050          Alaska Gateway School District
# 1  mixed - most recent  200010         Aleutian Region School District
# 2  mixed - most recent  200007  Aleutians East Borough School District
# 3  mixed - most recent  200180               Anchorage School District
# 4  mixed - most recent  200525          Annette Island School District
#
#   state_location city_location                    agency_type  enrollment  \
# 0             AK           Tok  Regular local school district       407.0
# 1             AK     Anchorage  Regular local school district        25.0
# 2             AK    Sand Point  Regular local school district       228.0
# 3             AK     Anchorage  Regular local school district     41856.0
# 4             AK    Metlakatla  Regular local school district       316.0
#
#    est_population_5_17  est_population_5_17_poverty exp_current_elsec_total  \
# ...

# %%
for col in district_data.columns:
  district_data = district_data[district_data[col] != 'Suppressed data']

for col in district_data.columns:
  district_data = district_data[district_data[col] != 'Not applicable']

# %%
district_data.shape
# Out:
# (9986, 27)

# %%
import numpy as np
district_data['District Student Performance Metric'] = 0.3 * np.array(district_data['read_test_pct_prof_midpt']).astype(np.float) + 0.3 * np.array(district_data['math_test_pct_prof_midpt']).astype(np.float) + 0.4 * np.array(district_data['grad_rate_midpt']).astype(np.float)
district_data.head(10)
# Out:
# <ipython-input-47-b53f55ab47b4>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   district_data['District Student Performance Metric'] = 0.3 * np.array(district_data['read_test_pct_prof_midpt']).astype(np.float) + 0.3 * np.array(district_data['math_test_pct_prof_midpt']).astype(np.float) + 0.4 * np.array(district_data['grad_rate_midpt']).astype(np.float)
#                    year   leaid                                lea_name  \
# 0   mixed - most recent  200050          Alaska Gateway School District
# 2   mixed - most recent  200007  Aleutians East Borough School District
# 3   mixed - most recent  200180               Anchorage School District
# ...

# %%
district_data['enrollment'] = np.array(district_data['enrollment']).astype(int)

# %%
district_data.columns
# Out:
# Index(['year', 'leaid', 'lea_name', 'state_location', 'city_location',
#        'agency_type', 'enrollment', 'est_population_5_17',
#        'est_population_5_17_poverty', 'exp_current_elsec_total',
#        'exp_current_instruction_total', 'exp_current_supp_serve_total',
#        'exp_current_sch_admin', 'exp_tech_supplies_services',
#        'exp_current_pupils', 'exp_current_instruc_staff',
#        'exp_current_general_admin', 'exp_current_student_transport',
#        'exp_current_food_serv', 'exp_nonelsec_community_serv',
#        'read_test_num_valid', 'read_test_pct_prof_midpt',
#        'math_test_num_valid', 'math_test_pct_prof_midpt', 'grad_rate_midpt',
#        'county_code', 'county_name', 'District Student Performance Metric'],
#       dtype='object')

# %%
from scipy.stats.mstats import zscore

x1 = np.divide((np.array(district_data['exp_current_elsec_total']).astype(int)), district_data['enrollment'])
x2 = np.divide((np.array(district_data['exp_current_instruction_total']).astype(int)), district_data['enrollment'])
x3 = np.divide((np.array(district_data['exp_current_supp_serve_total']).astype(int)), district_data['enrollment'])
x4 = np.divide((np.array(district_data['exp_current_sch_admin']).astype(int)), district_data['enrollment'])
x5 = np.divide((np.array(district_data['exp_tech_supplies_services']).astype(int)), district_data['enrollment'])


x6 = np.divide((np.array(district_data['exp_current_pupils']).astype(int)), district_data['enrollment'])
x7 = np.divide((np.array(district_data['exp_current_instruc_staff']).astype(int)), district_data['enrollment'])
x8 = np.divide((np.array(district_data['exp_current_general_admin']).astype(int)), district_data['enrollment'])
x9 = np.divide((np.array(district_data['exp_current_student_transport']).astype(int)), district_data['enrollment'])
#x10 = np.divide((np.array(district_data['exp_current_food_serv']).astype(int)), district_data['enrollment'])
#x11 = np.divide((np.array(district_data['exp_nonelsec_community_serv']).astype(int)), district_data['enrollment'])

# %%
x_input = np.stack((x2, x3, x4, x5, x6, x7, x8, x9), axis=1)
x_input
# Out:
# array([[17186.73218673, 18457.002457  ,  1331.6953317 , ...,
#          7464.37346437,   739.55773956,  1938.57493857],
#        [19030.70175439, 18675.43859649,  2521.92982456, ...,
#          6236.84210526,  2482.45614035,   114.03508772],
#        [ 9746.20126147,  6727.47037462,  1004.2287844 , ...,
#           613.93826453,   120.50840979,   552.96731651],
#        ...,
#        [15741.07142857, 11464.28571429,  1250.        , ...,
#           919.64285714,  2758.92857143,  1571.42857143],
#        [10072.07207207,  7122.26512227,   890.6048906 , ...,
#          1015.44401544,   423.42342342,   965.25096525],
#        [14117.11711712, 11702.7027027 ,  1405.40540541, ...,
#          2351.35135135,   972.97297297,   896.3963964 ]])

# %%
y_input = np.array(district_data['District Student Performance Metric'])
y_input
# Out:
# array([34.8, 49.2, 57.9, ..., 62.7, 66.6, 54.3])

# %%
#district_data.to_excel('cleaned_data.xlsx')

# %%
district_data = district_data.sort_values(by=['District Student Performance Metric'], ascending=False)
top_50_district_data = district_data.head(50)

# %%
top_50_district_data['total_exp'] = np.array(top_50_district_data['exp_current_sch_admin']).astype(np.float) + np.array(top_50_district_data['exp_tech_supplies_services']).astype(np.float) + np.array(top_50_district_data['exp_current_instruc_staff']).astype(np.float) + np.array(top_50_district_data['exp_current_general_admin']).astype(np.float) + np.array(top_50_district_data['exp_current_student_transport']).astype(np.float) + np.array(top_50_district_data['exp_current_food_serv']).astype(np.float) + np.array(top_50_district_data['exp_nonelsec_community_serv']).astype(np.float)
top_50_district_data
# Out:
# <ipython-input-55-b4578cb40f87>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
top_50_district_data['exp_current_sch_admin'] = np.divide(np.array(top_50_district_data['exp_current_sch_admin']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_tech_supplies_services'] = np.divide(np.array(top_50_district_data['exp_tech_supplies_services']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_current_instruc_staff'] = np.divide(np.array(top_50_district_data['exp_current_instruc_staff']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_current_general_admin'] = np.divide(np.array(top_50_district_data['exp_current_general_admin']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_current_student_transport'] = np.divide(np.array(top_50_district_data['exp_current_student_transport']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_current_food_serv'] = np.divide(np.array(top_50_district_data['exp_current_food_serv']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
top_50_district_data['exp_nonelsec_community_serv'] = np.divide(np.array(top_50_district_data['exp_nonelsec_community_serv']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
# Out:
# <ipython-input-56-39a139c35c26>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   top_50_district_data['exp_current_sch_admin'] = np.divide(np.array(top_50_district_data['exp_current_sch_admin']).astype(np.float), np.array(top_50_district_data['total_exp']).astype(np.double))
# <ipython-input-56-39a139c35c26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
np.mean(top_50_district_data['exp_current_sch_admin'])
# Out:
# 0.25947068660182576

# %%
np.mean(top_50_district_data['exp_tech_supplies_services'])
# Out:
# 0.08760128597338865

# %%
np.mean(top_50_district_data['exp_current_instruc_staff'])
# Out:
# 0.19048211844706917

# %%
np.mean(top_50_district_data['exp_current_general_admin'])
# Out:
# 0.12323958134875093

# %%
np.mean(top_50_district_data['exp_current_student_transport'])
# Out:
# 0.17925887553510866

# %%
np.mean(top_50_district_data['exp_current_food_serv'])
# Out:
# 0.129152141904699

# %%
np.mean(top_50_district_data['exp_nonelsec_community_serv'])
# Out:
# 0.03079531018915789

# %%
district_data['total_exp'] = np.array(district_data['exp_current_sch_admin']).astype(np.float) + np.array(district_data['exp_tech_supplies_services']).astype(np.float) + np.array(district_data['exp_current_instruc_staff']).astype(np.float) + np.array(district_data['exp_current_general_admin']).astype(np.float) + np.array(district_data['exp_current_student_transport']).astype(np.float) + np.array(district_data['exp_current_food_serv']).astype(np.float) + np.array(district_data['exp_nonelsec_community_serv']).astype(np.float)
district_data
# Out:
# <ipython-input-64-bcfa38769e5d>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   district_data['total_exp'] = np.array(district_data['exp_current_sch_admin']).astype(np.float) + np.array(district_data['exp_tech_supplies_services']).astype(np.float) + np.array(district_data['exp_current_instruc_staff']).astype(np.float) + np.array(district_data['exp_current_general_admin']).astype(np.float) + np.array(district_data['exp_current_student_transport']).astype(np.float) + np.array(district_data['exp_current_food_serv']).astype(np.float) + np.array(district_data['exp_nonelsec_community_serv']).astype(np.float)
# ...

# %%
district_data['exp_current_sch_admin'] = np.divide(np.array(district_data['exp_current_sch_admin']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_tech_supplies_services'] = np.divide(np.array(district_data['exp_tech_supplies_services']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_current_instruc_staff'] = np.divide(np.array(district_data['exp_current_instruc_staff']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_current_general_admin'] = np.divide(np.array(district_data['exp_current_general_admin']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_current_student_transport'] = np.divide(np.array(district_data['exp_current_student_transport']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_current_food_serv'] = np.divide(np.array(district_data['exp_current_food_serv']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
district_data['exp_nonelsec_community_serv'] = np.divide(np.array(district_data['exp_nonelsec_community_serv']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
# Out:
# <ipython-input-65-b77c1bbbdcd8>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   district_data['exp_current_sch_admin'] = np.divide(np.array(district_data['exp_current_sch_admin']).astype(np.float), np.array(district_data['total_exp']).astype(np.double))
# <ipython-input-65-b77c1bbbdcd8>:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
optimal_values = np.array([0.25947068660182576, 0.08760128597338865, 0.19048211844706917, 0.12323958134875093, 0.17925887553510866, 0.129152141904699, 0.03079531018915789])

# %%
np.sum(optimal_values)
# Out:
# 1.0

# %%
district_data['optimal_exp_current_sch_admin'] = 0.25947068660182576
district_data['optimal_exp_tech_supplies_services'] = 0.08760128597338865
district_data['optimal_exp_current_instruc_staff'] = 0.19048211844706917
district_data['optimal_exp_current_general_admin'] = 0.12323958134875093
district_data['optimal_exp_current_student_transport'] = 0.17925887553510866
district_data['optimal_exp_current_food_serv'] = 0.129152141904699
district_data['optimal_exp_nonelsec_community_serv'] = 0.03079531018915789

# %%
district_data
# Out:
#                       year    leaid                            lea_name  \
# 14453  mixed - most recent  3904660                          Solon City
# 13780  mixed - most recent  3904528      Chagrin Falls Exempted Village
# 13689  mixed - most recent  3904354                    Bay Village City
# 14195  mixed - most recent  3904431                      Mariemont City
# 14353  mixed - most recent  3904821                  Ottawa Hills Local
# ...                    ...      ...                                 ...
# 10268  mixed - most recent  3017040                     Lodge Grass H S
# 16580  mixed - most recent  4652770       Oelrichs School District 23-3
# 19466  mixed - most recent  5600960  Fremont County School District #38
# 11291  mixed - most recent  3176400            SANTEE COMMUNITY SCHOOLS
# 16581  mixed - most recent  4665460           Oglala Lakota County 65-1
#
#       state_location  city_location                    agency_type  \
# ...

# %%
district_data.to_excel('cleaned_data.xlsx')
